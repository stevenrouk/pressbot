# %% [markdown]
# # document-clustering
#
# Following along with Brandon Rose's document clustering tutorial on IMDB movie synopses.
#
# https://github.com/brandomr/document_cluster/blob/master/cluster_analysis.ipynb
#
# http://brandonrose.org/clustering
#
# http://brandonrose.org/top100

# %%
# %matplotlib inline

import bs4 as BeautifulSoup
import codecs
from collections import Counter
import matplotlib.pyplot as plt
import mpld3
import nltk
from nltk.stem.snowball import SnowballStemmer
import numpy as np
import os
import pandas as pd
import re
import requests
import seaborn as sns
from sklearn import feature_extraction
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Getting the IMDB movie synopsis data

# %%
# Get top 100 movie data from IMDB
r = requests.get('http://www.imdb.com/list/ls055592025/')
soup = BeautifulSoup.BeautifulSoup(r.text, 'html.parser')
list_items = soup.findAll('div', attrs={'class': 'list_item'})

URL_BASE = 'http://www.imdb.com'
SYNOPSIS_URL = URL_BASE + '{}' + 'synopsis'   # use with .format(url) for each movie

data = []
for item in list_items:
    number = item.find('div', attrs={'class': 'number'}).text
    info = item.find('div', attrs={'class': 'info'})
    title = info.find('b').text.split('\n')[0]
    year = info.find('span', attrs={'class': 'year_type'}).text
    description = item.find('div', attrs={'class': 'item_description'}).text
    description, length = description.split('. (')[0] + '.', description.split('. (')[1][:-2]
    partial_url = info.find('b').find('a')['href']
    full_url = URL_BASE + info.find('b').find('a')['href']
    synopsis_html = requests.get(SYNOPSIS_URL.format(partial_url)).text
    synopsis_soup = BeautifulSoup.BeautifulSoup(synopsis_html)
    synopsis = synopsis_soup.find('div', attrs={'id': 'swiki_body'}).text.strip()
    data.append([number, title, year, description, length, partial_url, full_url, synopsis])

# %%
titles = [movie[1] for movie in data]
synopses = [movie[7] for movie in data]

# %% [markdown]
# ## Stopwords, stemming, and tokenizing
# Stop words: common words that don't add to the meaning of the text
#
# Stemming: shortening a word to it's root, so that words like "programming", "programmed", and "programs" are all the same.
#
# Tokenizing: {{ fill info in here }}

# %%
# For this tutorial we'll use NLTK's stopwords, but sklearn also has a list of stopwords.
# (sklearn's list is actually longer, but includes some strange word choices like 'cry')
stopwords = nltk.corpus.stopwords.words('english')
stopwords_sklearn = feature_extraction.text.ENGLISH_STOP_WORDS

len(stopwords), len(stopwords_sklearn)
# Out:
# (153, 318)

# %%
# Load nltk's SnowballStemmer
stemmer = SnowballStemmer('english')

# %%
def tokenize(text):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = []
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

def tokenize_and_stem(text):
    return [stemmer.stem(t) for t in tokenize(text)]

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synopses:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %% [markdown]
# ## TF-IDF and Document Similarity

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                  min_df=0.2, stop_words='english',
                                  use_idf=True, tokenizer=tokenize_and_stem,
                                  ngram_range=(1,3))

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(synopses)

# %%
tfidf_matrix.shape
# Out:
# (100, 401)

# %%
sns.heatmap((tfidf_matrix * tfidf_matrix.T).A)
# Out:
# C:\Users\steve\Anaconda2\lib\site-packages\seaborn\matrix.py:134: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
# C:\Users\steve\Anaconda2\lib\site-packages\seaborn\matrix.py:142: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if yticklabels == []:

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
dist = 1 - cosine_similarity(tfidf_matrix)

# %% [markdown]
# ## K-means clustering

# %%
NUM_CLUSTERS = 5

km = KMeans(n_clusters=NUM_CLUSTERS)

km.fit(tfidf_matrix)

clusters = km.labels_.tolist()

# %%
df = pd.DataFrame(data,
                     index=[clusters],
                     columns=['id',
                              'title',
                              'year',
                              'desc',
                              'length',
                              'partial_url',
                              'full_url',
                              'synopses'
                             ]
                    )
df['cluster'] = clusters

df
# Out:
#       id                                              title    year  \
# 3     1.                                      The Godfather  (1972)
# 1     2.                           The Shawshank Redemption  (1994)
# 2     3.                                   Schindler's List  (1993)
# 3     4.                                        Raging Bull  (1980)
# 2     5.                                         Casablanca  (1942)
# 3     6.                                       Citizen Kane  (1941)
# 3     7.                                 Gone with the Wind  (1939)
# 1     8.                                   The Wizard of Oz  (1939)
# 2     9.                    One Flew Over the Cuckoo's Nest  (1975)
# 2    10.                                 Lawrence of Arabia  (1962)
# 1    11.                                            Vertigo  (1958)
# 1    12.                                             Psycho  (1960)
# 3    13.                             The Godfather: Part II  (1974)
# 1    14.                                  On the Waterfront  (1954)
# 1    15.                                       Sunset Blvd.  (1950)
# 2    16.                                       Forrest Gump  (1994)
# 3    17.                                 The Sound of Music  (1965)
# 0    18.                                       12 Angry Men  (1957)
# 1    19.                                    West Side Story  (1961)
# 2    20.                 Star Wars: Episode IV - A New Hope  (1977)
# 2    21.                              2001: A Space Odyssey  (1968)
# 4    22.                         E.T. the Extra-Terrestrial  (1982)
# 3    23.                           The Silence of the Lambs  (1991)
# 1    24.                                          Chinatown  (1974)
# 2    25.                       The Bridge on the River Kwai  (1957)
# 0    26.                                Singin' in the Rain  (1952)
# 4    27.                              It's a Wonderful Life  (1946)
# 2    28.  Dr. Strangelove or: How I Learned to Stop Worr...  (1964)
# 1    29.                                   Some Like It Hot  (1959)
# 3    30.                                            Ben-Hur  (1959)
# ..   ...                                                ...     ...
# 0    71.                       Mr. Smith Goes to Washington  (1939)
# 3    72.                                           Rain Man  (1988)
# 0    73.                                         Annie Hall  (1977)
# 1    74.                                            Tootsie  (1982)
# 1    75.                                              Fargo  (1996)
# 3    76.                                              Giant  (1956)
# 3    77.                                The Grapes of Wrath  (1940)
# 0    78.                                              Shane  (1953)
# 4    79.                                     The Green Mile  (1999)
# 2    80.                 Close Encounters of the Third Kind  (1977)
# 1    81.                                          Nashville  (1975)
# 3    82.                                            Network  (1976)
# 1    83.                                       The Graduate  (1967)
# 4    84.                                  American Graffiti  (1973)
# 0    85.                                  Good Will Hunting  (1997)
# 0    86.                                Terms of Endearment  (1983)
# 4    87.                                       Pulp Fiction  (1994)
# 4    88.                                  The African Queen  (1951)
# 0    89.                                         Stagecoach  (1939)
# 0    90.                               Mutiny on the Bounty  (1935)
# 2    91.                                 The Great Dictator  (1940)
# 1    92.                                 The Maltese Falcon  (1941)
# 0    93.                                  Wuthering Heights  (1939)
# 3    94.                                   Double Indemnity  (1944)
# 1    95.                                        Taxi Driver  (1976)
# 3    96.                              Rebel Without a Cause  (1955)
# 4    97.                                        Rear Window  (1954)
# 1    98.                                      The Third Man  (1949)
# 1    99.                                 North by Northwest  (1959)
# 0   100.                                Yankee Doodle Dandy  (1942)
#
#                                                  desc    length  \
# 3   The aging patriarch of an organized crime dyna...  175 mins
# 1   Two imprisoned men bond over a number of years...  142 mins
# 2   In German-occupied Poland during World War II,...  195 mins
# 3   An emotionally self-destructive boxer's journe...  129 mins
# 2   In Casablanca, Morocco in December 1941, a cyn...  102 mins
# 3   Following the death of a publishing tycoon, ne...  119 mins
# 3   A manipulative Southern belle carries on a tur...  238 mins
# 1   Dorothy Gale is swept away to a magical land i...  102 mins
# 2   A criminal pleads insanity after getting into ...  133 mins
# 2   The story of T.E. Lawrence, the English office...  216 mins
# 1   A San Francisco detective suffering from acrop...  128 mins
# 1   A Phoenix secretary embezzles $40,000 from her...  109 mins
# 3   The early life and career of Vito Corleone in ...  202 mins
# 1   An ex-prize fighter turned longshoreman strugg...  108 mins
# 1   A hack screenwriter writes a screenplay for a ...  110 mins
# 2   Forrest Gump, while not intelligent, has accid...  142 mins
# 3   A woman leaves an Austrian convent to become a...  174 mins
# 0   A jury holdout attempts to prevent a miscarria...   96 mins
# 1   Two youngsters from rival New York City gangs ...  152 mins
# 2   Luke Skywalker joins forces with a Jedi Knight...  121 mins
# 2   Humanity finds a mysterious, obviously artific...  149 mins
# 4   A troubled child summons the courage to help a...  115 mins
# 3   A young F.B.I. cadet must confide in an incarc...  118 mins
# 1   A private detective hired to expose an adulter...  130 mins
# 2   After settling his differences with a Japanese...  161 mins
# 0   A silent film production company and cast make...  103 mins
# 4   An angel helps a compassionate but despairingl...  130 mins
# 2   An insane general triggers a path to nuclear h...   95 mins
# 1   When two male musicians witness a mob hit, the...  120 mins
# 3   When a Jewish prince is betrayed and sent into...  212 mins
# ..                                                ...       ...
# 0   A naive man is appointed to fill a vacancy in ...  129 mins
# 3   Selfish yuppie Charlie Babbitt's father left a...  133 mins
# 0   Neurotic New York comedian Alvy Singer falls i...   93 mins
# 1   Michael Dorsey, an unsuccessful actor, disguis...  116 mins
# 1   Jerry Lundegaard's inept crime falls apart due...   98 mins
# 3   Sprawling epic covering the life of a Texas ca...  201 mins
# 3   A poor Midwest family is forced off of their l...  129 mins
# 0   A weary gunfighter attempts to settle down wit...  118 mins
# 4   The lives of guards on Death Row are affected ...  189 mins
# 2   After an encounter with U.F.O.s, a line worker...  137 mins
# 1   Over the course of a few hectic days, numerous...  159 mins
# 3   A television network cynically exploits a dera...  121 mins
# 1   A disillusioned college graduate finds himself...  106 mins
# 4   A couple of high school grads spend one final ...  110 mins
# 0   Will Hunting, a janitor at M.I.T., has a gift ...  126 mins
# 0   Follows hard-to-please Aurora looking for love...  132 mins
# 4   The lives of two mob hit men, a boxer, a gangs...  154 mins
# 4   In Africa during World War I, a gin-swilling r...  105 mins
# 0   A group of people traveling on a stagecoach fi...   96 mins
# 0   Midshipman Roger Byam joins Captain Bligh and ...  132 mins
# 2   Dictator Adenoid Hynkel tries to expand his em...  125 mins
# 1   A private detective takes on a case that invol...  100 mins
# 0   A servant in the house of Wuthering Heights te...  104 mins
# 3   An insurance representative lets himself be ta...  107 mins
# 1   A mentally unstable Vietnam War veteran works ...  113 mins
# 3   A rebellious young man with a troubled past co...  111 mins
# 4   A wheelchair-bound photographer spies on his n...  112 mins
# 1   Pulp novelist Holly Martins travels to shadowy...  104 mins
# 1   A hapless New York advertising executive is mi...  136 mins
# 0   The life of the renowned musical composer, pla...  126 mins
#
#           partial_url                              full_url  \
# 3   /title/tt0068646/  http://www.imdb.com/title/tt0068646/
# 1   /title/tt0111161/  http://www.imdb.com/title/tt0111161/
# 2   /title/tt0108052/  http://www.imdb.com/title/tt0108052/
# 3   /title/tt0081398/  http://www.imdb.com/title/tt0081398/
# 2   /title/tt0034583/  http://www.imdb.com/title/tt0034583/
# 3   /title/tt0033467/  http://www.imdb.com/title/tt0033467/
# 3   /title/tt0031381/  http://www.imdb.com/title/tt0031381/
# 1   /title/tt0032138/  http://www.imdb.com/title/tt0032138/
# 2   /title/tt0073486/  http://www.imdb.com/title/tt0073486/
# 2   /title/tt0056172/  http://www.imdb.com/title/tt0056172/
# 1   /title/tt0052357/  http://www.imdb.com/title/tt0052357/
# 1   /title/tt0054215/  http://www.imdb.com/title/tt0054215/
# 3   /title/tt0071562/  http://www.imdb.com/title/tt0071562/
# 1   /title/tt0047296/  http://www.imdb.com/title/tt0047296/
# 1   /title/tt0043014/  http://www.imdb.com/title/tt0043014/
# 2   /title/tt0109830/  http://www.imdb.com/title/tt0109830/
# 3   /title/tt0059742/  http://www.imdb.com/title/tt0059742/
# 0   /title/tt0050083/  http://www.imdb.com/title/tt0050083/
# 1   /title/tt0055614/  http://www.imdb.com/title/tt0055614/
# 2   /title/tt0076759/  http://www.imdb.com/title/tt0076759/
# 2   /title/tt0062622/  http://www.imdb.com/title/tt0062622/
# 4   /title/tt0083866/  http://www.imdb.com/title/tt0083866/
# 3   /title/tt0102926/  http://www.imdb.com/title/tt0102926/
# 1   /title/tt0071315/  http://www.imdb.com/title/tt0071315/
# 2   /title/tt0050212/  http://www.imdb.com/title/tt0050212/
# 0   /title/tt0045152/  http://www.imdb.com/title/tt0045152/
# 4   /title/tt0038650/  http://www.imdb.com/title/tt0038650/
# 2   /title/tt0057012/  http://www.imdb.com/title/tt0057012/
# 1   /title/tt0053291/  http://www.imdb.com/title/tt0053291/
# 3   /title/tt0052618/  http://www.imdb.com/title/tt0052618/
# ..                ...                                   ...
# 0   /title/tt0031679/  http://www.imdb.com/title/tt0031679/
# 3   /title/tt0095953/  http://www.imdb.com/title/tt0095953/
# 0   /title/tt0075686/  http://www.imdb.com/title/tt0075686/
# 1   /title/tt0084805/  http://www.imdb.com/title/tt0084805/
# 1   /title/tt0116282/  http://www.imdb.com/title/tt0116282/
# 3   /title/tt0049261/  http://www.imdb.com/title/tt0049261/
# 3   /title/tt0032551/  http://www.imdb.com/title/tt0032551/
# 0   /title/tt0046303/  http://www.imdb.com/title/tt0046303/
# 4   /title/tt0120689/  http://www.imdb.com/title/tt0120689/
# 2   /title/tt0075860/  http://www.imdb.com/title/tt0075860/
# 1   /title/tt0073440/  http://www.imdb.com/title/tt0073440/
# 3   /title/tt0074958/  http://www.imdb.com/title/tt0074958/
# 1   /title/tt0061722/  http://www.imdb.com/title/tt0061722/
# 4   /title/tt0069704/  http://www.imdb.com/title/tt0069704/
# 0   /title/tt0119217/  http://www.imdb.com/title/tt0119217/
# 0   /title/tt0086425/  http://www.imdb.com/title/tt0086425/
# 4   /title/tt0110912/  http://www.imdb.com/title/tt0110912/
# 4   /title/tt0043265/  http://www.imdb.com/title/tt0043265/
# 0   /title/tt0031971/  http://www.imdb.com/title/tt0031971/
# 0   /title/tt0026752/  http://www.imdb.com/title/tt0026752/
# 2   /title/tt0032553/  http://www.imdb.com/title/tt0032553/
# 1   /title/tt0033870/  http://www.imdb.com/title/tt0033870/
# 0   /title/tt0032145/  http://www.imdb.com/title/tt0032145/
# 3   /title/tt0036775/  http://www.imdb.com/title/tt0036775/
# 1   /title/tt0075314/  http://www.imdb.com/title/tt0075314/
# 3   /title/tt0048545/  http://www.imdb.com/title/tt0048545/
# 4   /title/tt0047396/  http://www.imdb.com/title/tt0047396/
# 1   /title/tt0041959/  http://www.imdb.com/title/tt0041959/
# 1   /title/tt0053125/  http://www.imdb.com/title/tt0053125/
# 0   /title/tt0035575/  http://www.imdb.com/title/tt0035575/
#
#                                              synopses  cluster
# 3   In late summer 1945, guests are gathered for t...        3
# 1   In 1947, Andy Dufresne (Tim Robbins), a banker...        1
# 2   The relocation of Polish Jews from surrounding...        2
# 3   The film opens in 1964, where an older and fat...        3
# 2   In the early years of World War II, December 1...        2
# 3   It's 1941, and newspaper tycoon Charles Foster...        3
# 3   The film opens in Tara, a cotton plantation ow...        3
# 1   Dorothy Gale (Judy Garland) is an orphaned tee...        1
# 2   In 1963 Oregon, Randle Patrick McMurphy (Nicho...        2
# 2   In 1935, T. E. Lawrence (Peter O'Toole) is kil...        2
# 1   A woman's face gives way to a kaleidoscope of ...        1
# 1   In a Phoenix hotel room on a Friday afternoon,...        1
# 3   The Godfather Part II presents two parallel st...        3
# 1   Terry Malloy (Marlon Brando) once dreamt of be...        1
# 1   The film opens with the camera tracking down S...        1
# 2   The film begins with a feather falling to the ...        2
# 3   The widowed, retired Austrian naval officer, C...        3
# 0   In a New York City courthouse, an eighteen-yea...        0
# 1   A fight set to music between an American gang,...        1
# 2   Note: Italicized paragraphs describe scenes ad...        2
# 2   To Richard Strauss' tone poem "Thus Spake Zara...        2
# 4   In a forested area overlooking a sprawling sub...        4
# 3   Promising FBI Academy student Clarice Starling...        3
# 1   Set in 1937 Los Angeles, a private investigato...        1
# 2   In the middle of World War II, two prisoners o...        2
# 0   Don Lockwood (Gene Kelly) is a popular silent ...        0
# 4   This movie is about a divine intervention by a...        4
# 2   At the Burpelson U.S. Air Force Base somewhere...        2
# 1   Joe and Jerry, a saxophonist and bassist, resp...        1
# 3   Judah Ben-Hur (Charlton Heston) is a wealthy m...        3
# ..                                                ...      ...
# 0   The governor of an unnamed western state, Hube...        0
# 3   Charlie Babbitt (Tom Cruise), a Los Angeles ca...        3
# 0   Annie Hall is a film about a comedian, Alvy Si...        0
# 1   Michael Dorsey is an actor living and working ...        1
# 1   The movie opens with a car towing a new tan Ol...        1
# 3   In the 1920s, Jordan "Bick" Benedict, Jr. (Roc...        3
# 3   After serving four years in prison for killing...        3
# 0                                                            0
# 4   The movie begins with an old man named Paul Ed...        4
# 2   In what appers to be the Sonoran Desert; in or...        2
# 1   The overarching plot takes place over five day...        1
# 3   The following synopsis has mostly been taken f...        3
# 1   The film explores the life of 21-year-old Ben ...        1
# 4   It's the last night of summer in 1962, and a n...        4
# 0   Though Will Hunting (Matt Damon) has genius-le...        0
# 0                                                            0
# 4   Late one morning in the Hawthorne Grill, a res...        4
# 4   An English spinster, Rose (Katharine Hepburn),...        4
# 0                                                            0
# 0                                                            0
# 2   During a battle in the last months of World Wa...        2
# 1   Private eye Sam Spade and his partner Miles Ar...        1
# 0                                                            0
# 3   Walter Neff (MacMurray) is a successful insura...        3
# 1   Travis Bickle (Robert De Niro) goes to a New Y...        1
# 3   Shortly after moving to Los Angeles with his p...        3
# 4   L.B. "Jeff" Jeffries (James Stewart) recuperat...        4
# 1   Sights of Vienna, Austria, flash across the sc...        1
# 1   At the end of an ordinary work day, advertisin...        1
# 0                                                            0
#
# [100 rows x 9 columns]

# %%
df['cluster'].value_counts()
# Out:
# 3    27
# 2    25
# 1    23
# 4    13
# 0    12
# Name: cluster, dtype: int64

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1]

"""for i in range(len(clusters)):
    print "Cluster {} words".format(i)
    
    for ind in order_centroids[i, :6]:
        part1 = vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0]
        part2 = part1.encode('utf-8', 'ignore')
        print '{}'.format(part2)"""
# Out:
# 'for i in range(len(clusters)):\n    print "Cluster {} words".format(i)\n    \n    for ind in order_centroids[i, :6]:\n        part1 = vocab_frame.ix[terms[ind].split(\' \')].values.tolist()[0][0]\n        part2 = part1.encode(\'utf-8\', \'ignore\')\n        print \'{}\'.format(part2)'
